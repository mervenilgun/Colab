# %% [markdown]
# ## 🎯 Random Forest ve Hiperparametre Ayarları
#
# ---
#
# ### 📌 1. Giriş: Random Forest Nedir?
#
# **Ana Fikir:**
# Random Forest, birçok karar ağacının birlikte çalıştığı bir topluluk (ensemble) öğrenme yöntemidir.
# Her bir ağaç verinin farklı bir alt kümesinde ve özelliklerin rastgele seçilen bir kısmında eğitilir.
# Sonuçta ağaçlar oy verir (sınıflandırma için çoğunluk oyu, regresyon için ortalama alınır).
#
# **Örnek benzetme:**
# Random Forest = Kalabalık bir uzmanlar grubu → Her biri farklı bir bakış açısı → Toplu karar → Daha doğru ve dengeli sonuç.
#
# ---
#
# ### 🧠 2. Random Forest'ın Faydaları
#
# - Aşırı öğrenmeye (overfitting) karşı dayanıklıdır.
# - Karar ağacından daha kararlı ve genelleme yeteneği yüksektir.
# - Feature importance (özellik önem sıralaması) sunar.
# - Hem sınıflandırma hem regresyon problemlerinde kullanılabilir.
#
# ---
#
# ### ⚙️ 3. Hiperparametreler
#
# | Parametre | Açıklama | Not |
# |-----------|----------|-----|
# | `n_estimators` | Oluşturulacak ağaç sayısı | Genelde ne kadar çok, o kadar iyi (ama yavaşlar) |
# | `max_depth` | Her ağacın derinliği | Aşırı öğrenmeyi engellemek için sınırlanabilir |
# | `min_samples_split` | Bir dalın bölünebilmesi için gereken minimum örnek sayısı | Daha yüksek → daha basit model |
# | `min_samples_leaf` | Bir yaprak düğümdeki minimum örnek sayısı | Daha yüksek → daha genel ağaçlar |
# | `max_features` | Her ağaç için değerlendirilecek maksimum özellik sayısı | `sqrt`, `log2`, ya da sayı olabilir |
# | `bootstrap` | Örnekleme yöntemi (`True` → örneklerle, `False` → tüm veri) | |
#
# ---

# %% [markdown]
# ![random-forest.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 🌲 Random Forest Nasıl Çalışır?
#
# ### 🔁 1. Temel Fikir: **Topluluk Öğrenmesi (Ensemble Learning)**
#
# Random Forest, "bir karar iyi olabilir ama birçok farklı kararı birleştirmek genelde daha iyidir" ilkesine dayanır.
# Bu yüzden *birçok karar ağacı* oluşturur ve onların tahminlerini birleştirir.
#
# - **Sınıflandırma** için: Çoğunluk oyu (majority voting)
# - **Regresyon** için: Tahminlerin ortalaması (average)
#
# ---
#
# ### 🔍 2. Random Forest Adımları
#
# #### 🧩 Adım 1: **Bootstrap Örnekleme (Veri Alt Kümesi Seçimi)**
#
# - Eğitim verisinden *tesadüfi olarak* (geri koymalı şekilde) bir alt küme seçilir.
# - Her ağaç, kendi örnekleme verisiyle eğitilir.
#   → Bu yüzden her ağaç farklı bir "bakış açısı" geliştirir.
#
# > Örnek: 100 gözlemden oluşan bir veri seti için her ağaç 100 rastgele (ve tekrar edebilir) örnek alır.
#
# ---
#
# #### 🎲 Adım 2: **Rasgele Özellik Seçimi (Feature Bagging)**
#
# - Her düğüm (node) için:
#   - Tüm özellikler arasından *rastgele seçilen küçük bir alt küme* değerlendirilir.
#   - Bu özellik kümesinden en iyi bölünme seçilir.
#
# > Bu sayede ağaçlar *birbirine benzememeye zorlanır*, çeşitlilik artar.
#
# ---
#
# #### 🌳 Adım 3: **Karar Ağaçlarının Eğitilmesi**
#
# - Bootstrap verisi ve rastgele özelliklerle birçok karar ağacı (örneğin 100 ağaç) eğitilir.
# - Her ağaç “tam bir model”dir ama diğerlerinden farklı öğrenmiştir.
#
# ---
#
# #### 🗳️ Adım 4: **Tahmin ve Oylama**
#
# - Yeni bir veri örneği geldiğinde, her ağaç bir tahminde bulunur.
# - Tüm tahminler birleştirilir:
#
#   - **Sınıflandırma için**: En çok tahmin edilen sınıf seçilir.
#     (örneğin: [‘A’, ‘A’, ‘B’, ‘A’, ‘B’] → Tahmin = ‘A’)
#
#   - **Regresyon için**: Tahminlerin ortalaması alınır.
#     (örneğin: [5.2, 4.9, 5.1] → Tahmin = 5.07)
#
# ---
#
# ### 📌 Neden Random Forest Daha Güçlüdür?
#
# | Özellik | Açıklama |
# |--------|----------|
# | ✅ Çeşitlilik | Her ağaç farklı veri ve özelliklerle eğitilir → farklı öğrenme |
# | ✅ Düşük varyans | Ağaçlar birlikte karar verince tek bir ağacın hatası bastırılır |
# | ✅ Aşırı öğrenmeye dayanıklı | Karar ağaçları overfit edebilir, ama RF genel resmi daha iyi yakalar |
# | ✅ Özellik önemini gösterir | Hangi özelliklerin tahminde ne kadar etkili olduğunu görebiliriz |
#
# ---
#
# ### 🧠 Sezgisel Anlatım Örneği: "Sınıf Temsilcisi Seçimi"
#
# Bir sınıfta temsilci seçilecek.
# Her öğrenci ailesiyle, arkadaşlarıyla ve öğretmeniyle konuşarak bir aday belirliyor (farklı bilgiler → farklı kararlar).
# Sonra herkes oy kullanıyor ve en çok oy alan kişi seçiliyor.
# → Bu şekilde topluluğun geneline daha uygun bir karar veriliyor.
#
# ---

# %% [markdown]
# ## ✅ Temel Kavramlar Listesi
#
# 1. **Ensemble Learning (Topluluk Öğrenmesi)**
# 2. **Bagging (Bootstrap Aggregating)**
# 3. **Boosting**
# 4. **Stacking (İstifleme)**
# 5. **Voting Classifier (Oylama Sınıflandırıcı)**
# 6. **Feature Bagging (Özellik Alt Kümesi Seçimi)**
# 7. **Out-of-Bag Error (OOB Error)**
# 8. **Bias-Variance Trade-off (Yanlılık-Varyans Dengesi)**
# 9. **Overfitting & Underfitting (Aşırı ve Yetersiz Öğrenme)**
# 10. **Variance Reduction (Varyans Azaltımı)**
# 11. **Randomization (Rastgelelik İlkesi)**
#
# ---
#
#
# ## 🧠 1. Ensemble Learning (Topluluk Öğrenmesi)
#
# > **Tanım:** Birden fazla makine öğrenmesi modelini bir araya getirerek, tek bir güçlü model oluşturma yaklaşımıdır.
# > **Amaç:** Bireysel modellerin zayıflıklarını dengeleyip daha iyi performans elde etmek.
# > **Örnekler:** Bagging, Boosting, Stacking
#
# ---
#
# ## 🧺 2. Bagging (Bootstrap Aggregating)
#
# > **Tanım:** Verinin rastgele alt kümeleriyle (bootstrap örnekleme) farklı modeller eğitilir ve tahminler birleştirilir.
# > **Amaç:** Varyansı azaltmak, overfitting’i önlemek.
# > **Klasik Örnek:** Random Forest
# > **Tahmin:** Sınıflandırma → çoğunluk oyu | Regresyon → ortalama
#
# ---
#
# ## 🚀 3. Boosting
#
# > **Tanım:** Zayıf modeller art arda eğitilir; her model bir öncekinde yapılan hataları düzeltmeye çalışır.
# > **Amaç:** Bias’ı azaltmak, daha güçlü bir model oluşturmak.
# > **Örnek Algoritmalar:** AdaBoost, Gradient Boosting, XGBoost, LightGBM
# > **Özellik:** Modeller sıralı ve birbirine bağlıdır (farklı olarak bagging'de modeller paraleldir)
#
# ---
#
# ## 🧱 4. Stacking
#
# > **Tanım:** Farklı algoritmalar bir arada eğitilir, çıktılar başka bir modelle birleştirilir (meta-learner).
# > **Amaç:** Farklı modellerin güçlü yanlarını birleştirmek.
# > **Yapı:** Taban modeller + Meta model
# > **Örnek:** Lojistik regresyon + karar ağacı + kNN → üstte bir regresyon modeli
#
# ---
#
# ## 🗳️ 5. Voting Classifier
#
# > **Tanım:** Farklı modellerin tahminleri alınır, en çok önerilen sınıf seçilir.
# > **Yöntemler:**
# > - **Hard Voting:** Sınıf oylaması
# > - **Soft Voting:** Sınıf olasılıklarının ortalaması
#
# ---
#
# ## 🧩 6. Feature Bagging
#
# > **Tanım:** Her ağacın her düğümünde tüm özellikler yerine rastgele bir alt küme kullanılması.
# > **Random Forest’ın temel özelliğidir.**
# > **Amaç:** Ağaçların farklı kararlar vermesini sağlamak (çeşitlilik)
#
# ---
#
# ## 🎯 7. Out-of-Bag Error (OOB Error)
#
# > **Tanım:** Bootstrap sırasında seçilmeyen örnekler (yaklaşık %30), modelin doğruluğunu test etmek için kullanılır.
# > **Avantaj:** Cross-validation yapmadan doğruluk tahmini yapılabilir.
#
#
#
# ---
#
# ## 🎯 Out-of-Bag Error (OOB Error) Nedir?
#
# ### 🔹 Önce hatırlayalım: Bagging ne yapıyordu?
#
# - Random Forest’ta her ağaç **bootstrap** yöntemiyle eğitilir.
# - Yani eğitim verisinden **geri koymalı** olarak örnekler seçilir.
# - Bu demektir ki bazı gözlemler **birden fazla kez seçilir**, bazıları ise **hiç seçilmez**.
#
# 📌 Ortalama olarak, her bootstrap örneğinde veri setinin **%63'ü** kullanılır.
# Geriye kalan **%37’lik kısım** → o ağaca **“hiç gösterilmemiş”** olur.
#
# ---
#
# ### 💡 İşte burada devreye giriyor: OOB (Out-of-Bag)
#
# > **Fikir:**
# > Eğer bir gözlem bir ağacın eğitiminde *yer almadıysa*, o ağaç bu gözlem için *bağımsız bir test* işlevi görebilir.
#
# Yani:
# - Bir gözlem için, onu görmeyen ağaçların tahminlerine bakılır.
# - Bu tahminler birleştirilir (oylama/ortalama).
# - Sonuçla gerçek sınıf karşılaştırılır.
# - Böylece **modelin doğruluğu** hesaplanabilir → *OOB Error*.
#
# ---
#
# ### 📊 Avantajı Ne?
#
# ✅ **Cross-validation yapmadan doğruluk tahmini sağlar**
# * OOB iyi bir “erken uyarı sistemi” gibidir.
# * CV ise “tam sağlık taraması”dır.
# ✅ Ekstra zaman harcamadan, modelin dışsal başarımını ölçer
# ✅ Özellikle büyük veri setlerinde çok faydalıdır
#
# ---
#
# ### 🔍 Biraz Kod Gözlemi
#
# ```python
# from sklearn.ensemble import RandomForestClassifier
#
# # OOB tahminlerini aktif edelim
# model = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# model.fit(X_train, y_train)
#
# # OOB skoru
# print("Out-of-Bag Score:", model.oob_score_)
# ```
#
# > Bu çıktı, modelin **cross-validation olmadan** elde ettiği test skoruna benzer bir sonuç verir.
#
# ---
#
# ## 🧠 Özetle OOB Error:
# - Random Forest’ın içinde **yerleşik bir test yöntemi** gibidir.
# - Modelin **daha önce görmediği** verilerle ne kadar iyi performans gösterdiğini tahmin eder.
# - Özellikle hızlı doğrulama ve model karşılaştırması için çok kullanışlıdır.
#
# ---
#
#
# ## ⚖️ 8. Bias-Variance Trade-off
#
# > **Tanım:** Basit modeller yüksek bias (yanlılık), kompleks modeller yüksek varyans hatası yapar.
# > **Amaç:** Bu ikisi arasında doğru dengeyi bulmak.
# > **Random Forest:** Varyansı azaltır, bias’ı çok artırmaz → dengelidir.
#
# ---
#
# ## 🔥 9. Overfitting & Underfitting
#
# - **Overfitting (Aşırı Öğrenme):** Model veriye ezber yapar, genelleme yapamaz.
# - **Underfitting (Yetersiz Öğrenme):** Model çok basittir, veriyi öğrenemez.
# - **Random Forest genelde overfitting’i azaltmak için kullanılır.**
#
# ---
#
# ## 📉 10. Variance Reduction
#
# > **Tanım:** Bagging ile aynı veride farklı kararlar veren modellerin ortalaması alınarak hata dalgalanması azaltılır.
# > **Random Forest’ın gücü burada yatar.**
#
# ---
#
# ## 🎲 11. Randomization (Rastgelelik)
#
# > **Tanım:** Verideki örnekler ve özelliklerin rastgele seçilmesi, modelin çeşitliliğini artırır.
# > **Yarar:** Ağaçlar aynı veriyle aynı sonuçları üretmez → overfitting riski düşer.
#
# ---

# %%
# Random Forest ile 24 Özellikli Veri Setinde Eğitim Süreci

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Veri Seti Oluşturma (24 özellikli sentetik sınıflandırma verisi)
X, y = make_classification(n_samples=1000, n_features=24, n_informative=10, n_redundant=5,
                           n_clusters_per_class=2, random_state=42)

# Eğitim ve test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 2. Random Forest Modeli
model = RandomForestClassifier(
    n_estimators=100,
    max_features="sqrt",  # her düğümde sqrt(24) ≈ 4.9 → yaklaşık 5 özellik kullanılır
    random_state=42
)
model.fit(X_train, y_train)

# 3. Tahmin ve Performans Değerlendirmesi
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# 4. Özellik Önemleri (Feature Importances)
feature_names = [f"feature_{i}" for i in range(24)]
importances = pd.Series(model.feature_importances_, index=feature_names)

plt.figure(figsize=(10, 6))
sns.barplot(x=importances.sort_values(ascending=False), y=importances.sort_values(ascending=False).index)
plt.title("Özellik Önemleri (Feature Importances)")
plt.xlabel("Önem Skoru")
plt.ylabel("Özellikler")
plt.tight_layout()
plt.show()

# 5. Tek bir ağacın görselleştirilmesi (isteğe bağlı)
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 10))
plot_tree(model.estimators_[0], max_depth=3, feature_names=feature_names, filled=True, fontsize=10)
plt.title("Random Forest İçindeki Bir Ağaç (İlk Ağaç)")
plt.show()
# Out:
# Accuracy: 0.9066666666666666
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       155
#            1       0.89      0.92      0.90       145
#
#     accuracy                           0.91       300
#    macro avg       0.91      0.91      0.91       300
# weighted avg       0.91      0.91      0.91       300

# %%
# Random Forest ile Iris Veri Setinde Eğitim, Ağaç Görselleştirme ve OOB vs CV Karşılaştırması

from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
from sklearn.tree import plot_tree
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# 1. Veri Seti Yükleme
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

# %%
# Eğitim ve test ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 2. Random Forest Modeli (OOB etkin)
model_oob = RandomForestClassifier(
    n_estimators=100,
    max_features="sqrt",
    oob_score=True,
    random_state=42
)
model_oob.fit(X_train, y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=42)

# %%
# 3. OOB Skoru ve Test Başarımı
print("OOB Score:", model_oob.oob_score_)
print("Test Accuracy:", accuracy_score(y_test, model_oob.predict(X_test)))
# Out:
# OOB Score: 0.9428571428571428
# Test Accuracy: 1.0

# %%
# 4. Cross-Validation ile Performans Ölçümü
cv_scores = cross_val_score(model_oob, X, y, cv=5)
print("CV Scores:", cv_scores)
print("CV Mean Accuracy:", np.mean(cv_scores))
# Out:
# CV Scores: [0.96666667 0.96666667 0.93333333 0.96666667 1.        ]
# CV Mean Accuracy: 0.9666666666666668

# %%
# 5. Özellik Önemleri (Feature Importances)
importances = pd.Series(model_oob.feature_importances_, index=feature_names)
plt.figure(figsize=(8, 5))
sns.barplot(x=importances.sort_values(ascending=False), y=importances.sort_values(ascending=False).index)
plt.title("Özellik Önemleri (Feature Importances)")
plt.xlabel("Önem Skoru")
plt.ylabel("Özellikler")
plt.tight_layout()
plt.show()

# %%
# 6. Birden Fazla Ağacın Görselleştirilmesi
for i in range(3):
    plt.figure(figsize=(16, 8))
    plot_tree(
        model_oob.estimators_[i],
        max_depth=3,
        feature_names=feature_names,
        class_names=iris.target_names,
        filled=True,
        fontsize=10
    )
    plt.title(f"Random Forest - Ağaç {i+1}")
    plt.show()

# %%
# 7. Kök Özellikleri Gözlemi (İlk 5 Ağaç)
print("--- Kök Düğüm Özellikleri ---")
for i, tree in enumerate(model_oob.estimators_[:]):
    root_feature_index = tree.tree_.feature[0]
    print(f"Ağaç {i+1} kök özelliği: {feature_names[root_feature_index]}")
# Out:
# --- Kök Düğüm Özellikleri ---
# Ağaç 1 kök özelliği: petal width (cm)
# Ağaç 2 kök özelliği: petal width (cm)
# Ağaç 3 kök özelliği: petal length (cm)
# Ağaç 4 kök özelliği: petal length (cm)
# Ağaç 5 kök özelliği: petal width (cm)
# Ağaç 6 kök özelliği: petal width (cm)
# Ağaç 7 kök özelliği: sepal length (cm)
# Ağaç 8 kök özelliği: sepal length (cm)
# Ağaç 9 kök özelliği: sepal length (cm)
# Ağaç 10 kök özelliği: petal width (cm)
# Ağaç 11 kök özelliği: petal length (cm)
# Ağaç 12 kök özelliği: petal width (cm)
# Ağaç 13 kök özelliği: petal length (cm)
# Ağaç 14 kök özelliği: petal width (cm)
# Ağaç 15 kök özelliği: petal width (cm)
# Ağaç 16 kök özelliği: petal length (cm)
# Ağaç 17 kök özelliği: sepal length (cm)
# Ağaç 18 kök özelliği: petal length (cm)
# Ağaç 19 kök özelliği: petal length (cm)
# Ağaç 20 kök özelliği: petal length (cm)
# Ağaç 21 kök özelliği: petal width (cm)
# Ağaç 22 kök özelliği: petal width (cm)
# Ağaç 23 kök özelliği: petal length (cm)
# ...

# %% [markdown]
# # DOĞRUSAL VERİ SETLERİNDE RANDOM FOREST

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Veri Setini İndir
path = "/content/drive/MyDrive/KAIRU/Kurumsal/Acun Medya Eğitimi/datasets/student-por.csv"
df = pd.read_csv(path)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# 2. Kategorik Değişkenleri Sayısal Değerlere Çevir
df_encoded = df.copy()
label_encoders = {}
for col in df_encoded.select_dtypes(include='object').columns:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col])
    label_encoders[col] = le

#df_ = df_encoded[['G1','G2','G3']]
#X = df_.drop(columns=['G3'])  # Dilersen G1, G2'yi ekleyebilirsin
#y = df_['G3']


# 3. Hedef değişken: G3 (final notu), G1 ve G2 çıkarılabilir (ön bilgi içerdiği için)

X = df_encoded.drop(columns=['G3'])  # Dilersen G1, G2'yi ekleyebilirsin
y = df_encoded['G3']

# 4. Eğitim/Test Ayrımı
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 5. Modeli Kur ve Eğit
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# 6. Tahmin ve Değerlendirme
y_pred = model.predict(X_test)
print("R2 Score:", r2_score(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))

# 7. Gerçek vs Tahmin Grafiği
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([0, 20], [0, 20], '--r')
plt.xlabel("Gerçek G3")
plt.ylabel("Tahmin Edilen G3")
plt.title("Random Forest ile G3 Tahmini")
plt.tight_layout()
plt.show()

# 8. Özellik Önemleri
importances = pd.Series(model.feature_importances_, index=X.columns)
importances.sort_values(ascending=False).head(10).plot(kind='barh')
plt.title("En Önemli 10 Özellik")
plt.xlabel("Önemi")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# R2 Score: 0.8564423417188682
# Mean Squared Error: 1.5874815384615384

# %% [markdown]
# Harika! Öğrencilere bir veri setini anlatırken hikayesini paylaşmak, sadece sayılarla değil, **gerçek dünya bağlamıyla öğrenmeyi** derinleştirir. İşte **Parkinsons Telemonitoring veri setinin hikayesi**, anlatı formatında sade ve etkileyici şekilde hazırlanmıştır:
#
# ---
#
# ## 🎓 Veri Seti Hikayesi: Parkinsons Telemonitoring
#
# ### 🧠 Konu: Parkinson Hastalığı Takibi
#
# Parkinson hastalığı, merkezi sinir sistemini etkileyen ve özellikle hareket bozukluklarına yol açan kronik bir nörolojik rahatsızlıktır. Zamanla yavaş yavaş ilerler, hastalarda titreme, kas sertliği ve motor koordinasyon bozuklukları gibi belirtiler görülür.
#
# Parkinson’un takibi, hastalığın ilerleme hızını gözlemlemek, tedavi yanıtlarını değerlendirmek ve bireyselleştirilmiş sağlık çözümleri geliştirmek açısından çok önemlidir.
#
# ---
#
# ## 📊 Veri Setinin Amacı
#
# Bu veri seti, **erken evre Parkinson hastalığına sahip 42 bireyin** motor semptomlarını **uzaktan (telemonitoring)** izlemek amacıyla oluşturulmuştur.
#
# Araştırmacılar şunu sormuştu:
#
# > “Ses kayıtlarındaki biyobelirteçlerle, Parkinson hastalığının şiddetini doğru bir şekilde tahmin edebilir miyiz?”
#
# Amaç, hastaların ses verilerinden yola çıkarak Parkinson şiddetini gösteren **UPDRS skorlarını (Unified Parkinson's Disease Rating Scale)** tahmin etmektir.
#
# ---
#
# ## 🧾 Veri Setinin İçeriği
#
# - **Toplam 42 birey** (erkek ve kadın)
# - **6 aylık süreç boyunca** 5875 ses kaydı
# - Her hastadan ses özellikleri çıkarılmış:
#   - Sesin titrekliği (jitter)
#   - Frekans varyasyonları
#   - Harmonik yapı
#   - Entropi ölçümleri
#   - Enerji dağılımı gibi teknik ses özellikleri
#
# - Hedef değişkenler:
#   - `motor_UPDRS`: Motor semptomlara ait skor (0–140 arası)
#   - `total_UPDRS`: Genel Parkinson skoru (0–199 arası)
#
# Veri setinde ayrıca her bireyin **zamanla** nasıl ilerlediği `test_time` ile takip edilebiliyor. Ancak model kurarken bu bağımlılıklar dikkatlice ele alınmalı.
#
# ---
#
# ## 💡 Bu Veri Seti ile Ne Öğrenilebilir?
#
# - **Regresyon modelleri** nasıl kurulur?
# - **Doğrusal olmayan ilişkiler** nasıl modellenir? (Random Forest gibi)
# - **Özellik önem sıralaması** ile hangi ses parametrelerinin daha belirleyici olduğu öğrenilir
# - **Gerçek dünya sağlık verisi** ile çalışmanın hassasiyetleri ve uygulama zorlukları anlaşılır
#
# ---
#
# ## 🧬 Gerçek Hayattaki Yansıması
#
# Bu tür bir sistem sayesinde:
# - Hastalar evden takip edilebilir,
# - Kliniklere daha az gitmek zorunda kalırlar,
# - Uzman doktorlar uzaktan hastalık şiddetini takip edebilir.
#
# Yani bu veri seti, **uzaktan sağlık izleme sistemlerinin temelini** oluşturabilecek teknolojik bir adıma dayanıyor.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Veri Setini Yükle
url = "/content/drive/MyDrive/KAIRU/Kurumsal/Acun Medya Eğitimi/datasets/parkinsons_updrs.data"
df = pd.read_csv(url)

# %%
# 2. Temel Bilgiler
df.shape
# Out:
# (5875, 22)

# %%
df.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   age            5875 non-null   int64
#  2   sex            5875 non-null   int64
#  3   test_time      5875 non-null   float64
#  4   motor_UPDRS    5875 non-null   float64
#  5   total_UPDRS    5875 non-null   float64
#  6   Jitter(%)      5875 non-null   float64
#  7   Jitter(Abs)    5875 non-null   float64
#  8   Jitter:RAP     5875 non-null   float64
#  9   Jitter:PPQ5    5875 non-null   float64
#  10  Jitter:DDP     5875 non-null   float64
#  11  Shimmer        5875 non-null   float64
#  12  Shimmer(dB)    5875 non-null   float64
#  13  Shimmer:APQ3   5875 non-null   float64
#  14  Shimmer:APQ5   5875 non-null   float64
#  15  Shimmer:APQ11  5875 non-null   float64
#  16  Shimmer:DDA    5875 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['subject#', 'age', 'sex', 'test_time', 'motor_UPDRS', 'total_UPDRS',
#        'Jitter(%)', 'Jitter(Abs)', 'Jitter:RAP', 'Jitter:PPQ5', 'Jitter:DDP',
#        'Shimmer', 'Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'Shimmer:APQ11', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'PPE'],
#       dtype='object')

# %% [markdown]
# Tabii ki, **Parkinsons Telemonitoring** veri setindeki değişkenlerin anlamlarını aşağıda bulabilirsiniz:
#
# - **subject#**: Her bir hastaya atanmış benzersiz kimlik numarası.
#
# - **age**: Hastanın yaşı (yıl cinsinden).
#
# - **sex**: Hastanın cinsiyeti; 0 = erkek, 1 = kadın.
#
# - **test_time**: İlk ziyaret tarihinden itibaren geçen süre (gün cinsinden).
#
# - **motor_UPDRS**: Motor Unified Parkinson's Disease Rating Scale (UPDRS) skoru; hastanın motor fonksiyonlarını değerlendiren bir ölçek.
#
# - **total_UPDRS**: Toplam UPDRS skoru; hem motor hem de motor dışı semptomları kapsayan genel bir değerlendirme.
#
# - **Jitter(%)**: Ses frekansındaki kısa süreli rastgele dalgalanmaların yüzdesi; ses titremesinin bir ölçütü.
#
# - **Jitter(Abs)**: Mutlak jitter değeri; ses frekansındaki kısa süreli rastgele dalgalanmaların mutlak değeri.
#
# - **Jitter:RAP**: RAP (Relative Average Perturbation); belirli bir süre boyunca frekans pertürbasyonlarının ortalaması.
#
# - **Jitter:PPQ5**: PPQ5 (Pitch Perturbation Quotient); 5 periyotluk bir pencere boyunca frekans pertürbasyonlarının ortalaması.
#
# - **Jitter:DDP**: DDP (Divergence of Distinctive Points); jitter RAP değerinin üç katı olarak hesaplanır.
#
# - **Shimmer**: Ses genliğindeki kısa süreli rastgele dalgalanmaların yüzdesi; sesin şiddetindeki titremelerin bir ölçütü.
#
# - **Shimmer(dB)**: Desibel cinsinden shimmer değeri; ses genliğindeki dalgalanmaların desibel olarak ifadesi.
#
# - **Shimmer:APQ3**: APQ3 (Amplitude Perturbation Quotient); 3 periyotluk bir pencere boyunca genlik pertürbasyonlarının ortalaması.
#
# - **Shimmer:APQ5**: APQ5; 5 periyotluk bir pencere boyunca genlik pertürbasyonlarının ortalaması.
#
# - **Shimmer:APQ11**: APQ11; 11 periyotluk bir pencere boyunca genlik pertürbasyonlarının ortalaması.
#
# - **Shimmer:DDA**: DDA (Divergence of Distinctive Amplitudes); shimmer APQ3 değerinin üç katı olarak hesaplanır.
#
# - **NHR**: Noise-to-Harmonics Ratio; ses sinyalindeki gürültü enerjisinin harmonik bileşenlere oranı.
#
# - **HNR**: Harmonics-to-Noise Ratio; harmonik bileşenlerin gürültü enerjisine oranı.
#
# - **RPDE**: Recurrence Period Density Entropy; ses sinyalinin tekrarlayan periyotlarının yoğunluk entropisi, sesin karmaşıklığını ölçer.
#
# - **DFA**: Detrended Fluctuation Analysis; ses sinyalinin fraktal ölçeklenme özelliklerini analiz eder.
#
# - **PPE**: Pitch Period Entropy; ses periyotlarının entropisi, ses tonunun değişkenliğini ölçer.
#
# Bu değişkenler, Parkinson hastalığının ilerleyişini ve semptomların şiddetini değerlendirmek için kullanılır. Özellikle sesle ilgili ölçümler, hastalığın motor semptomlarının uzaktan izlenmesi açısından önemlidir.
#
# Daha fazla bilgi için veri setinin orijinal açıklamasına başvurabilirsiniz: [Parkinsons Telemonitoring Veri Seti](https://archive.ics.uci.edu/ml/datasets/parkinsons+telemonitoring)

# %%
df.isnull().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# # MULTICOLLINEARITY İÇİN VIF HESAPLAMA
# Gerekli değil ama faydasını gözlemleyelim.
#
# LINEAR,RIDGE, LASSO için ÖNEMLİ UNUTMA!

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler



# Gerekli sütunları seç (hedef ve kimlik bilgileri hariç)
X = df.drop(columns=["subject#"])

# VIF hesaplaması için önce ölçeklendirme yap
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# VIF hesapla
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X_scaled, i) for i in range(X_scaled.shape[1])]
# Bilimsel gösterimi kapat (float formatını belirle)
pd.options.display.float_format = '{:,.2f}'.format

# Sonuçları sırala ve göster
vif_data_sorted = vif_data.sort_values(by="VIF", ascending=False)
print(vif_data_sorted)
# Out:
#           Feature           VIF
# 12   Shimmer:APQ3 23,992,525.17
# 15    Shimmer:DDA 23,992,471.36
# 9      Jitter:DDP  1,324,554.12
# 7      Jitter:RAP  1,324,317.77
# 10        Shimmer        173.76
# 5       Jitter(%)         89.36
# 11    Shimmer(dB)         76.92
# 13   Shimmer:APQ5         52.85
# 8     Jitter:PPQ5         31.04
# 14  Shimmer:APQ11         15.37
# 4     total_UPDRS         10.84
# 3     motor_UPDRS         10.59
# 16            NHR          8.60
# 6     Jitter(Abs)          7.98
# 17            HNR          5.50
# 20            PPE          4.50
# 18           RPDE          2.11
# 19            DFA          1.72
# 1             sex          1.39
# 0             age          1.18
# 2       test_time          1.02

# %%
df['age_group'] = pd.cut(df['age'], bins=[30, 50, 60, 70, 90], labels=["30-50", "50-60", "60-70", "70+"])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["age_group_encoded"] = le.fit_transform(df["age_group"])

# %%
df.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0       5.64        28.20        34.40       0.01
# 1         1   72    0      12.67        28.45        34.89       0.00
# 2         1   72    0      19.68        28.70        35.39       0.00
# 3         1   72    0      25.65        28.91        35.81       0.01
# 4         1   72    0      33.64        29.19        36.38       0.00
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer:APQ5  Shimmer:APQ11  \
# 0         0.00        0.00         0.00  ...          0.01           0.02
# 1         0.00        0.00         0.00  ...          0.01           0.02
# 2         0.00        0.00         0.00  ...          0.01           0.01
# 3         0.00        0.00         0.00  ...          0.01           0.02
# 4         0.00        0.00         0.00  ...          0.01           0.02
#
#    Shimmer:DDA  NHR   HNR  RPDE  DFA  PPE  age_group  age_group_encoded
# ...

# %%
#3. Hedef ve Özellikleri Ayır
# 'motor_UPDRS' tahmin edilecek değişken, kişi bilgilerini hariç tutuyoruz
X = df.drop(columns=['subject#','motor_UPDRS', 'total_UPDRS', 'test_time'])

y = df['motor_UPDRS']

# %% [markdown]
# Değişken	Neden silindi?
# * subject#	Kimlik bilgisi, ezberlemeye neden olur
# * test_time	Zamansal bağımlılık yaratır, data leakage riski taşır
# * total_UPDRS	Hedefe aşırı yakın, bilgi sızıntısı riski taşır

# %%
#3. Hedef ve Özellikleri VIF'e göre ayarla (VIF hesapladıktan sonra çalıştır.)
# 'motor_UPDRS' tahmin edilecek değişken, kişi bilgilerini hariç tutuyoruz
X = df.drop(columns=['subject#','motor_UPDRS', 'total_UPDRS', 'test_time',
    "Jitter:RAP",
    "Jitter:PPQ5",
    "Jitter:DDP",
    "Shimmer(dB)",
    "Shimmer:APQ3",
    "Shimmer:APQ5",
    "Shimmer:APQ11",
    "Shimmer:DDA",
    "total_UPDRS",
    "age_group",
    ])

y = df['motor_UPDRS']

# %%
# 4. Eğitim ve Test Verisine Ayır
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 5. Modeli Kur ve Eğit
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# 6. Tahmin ve Değerlendirme
y_pred = model.predict(X_test)
print("R2 Score:", r2_score(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.9071129213608317
# Mean Squared Error: 6.05377656642344

# %%
# 7. Gerçek vs Tahmin Grafiği
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r')
plt.xlabel("Gerçek motor_UPDRS")
plt.ylabel("Tahmin Edilen motor_UPDRS")
plt.title("Random Forest - motor_UPDRS Tahmini")
plt.tight_layout()
plt.show()

# %%
# 8. Özellik Önemleri
importances = pd.Series(model.feature_importances_, index=X.columns)
importances.sort_values(ascending=False).head(10).plot(kind='barh')
plt.title("En Önemli 10 Özellik")
plt.xlabel("Önemi")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# Yaş Çok belirgin. şimdi onu inceleyelim

# %%
sns.scatterplot(x=df['age'], y=df['motor_UPDRS'])
plt.title("Yaş vs motor_UPDRS")
plt.show()

# %% [markdown]
# “Yaş arttıkça motor UPDRS skoru genel olarak yükseliyor gibi görünüyor.
# Ama dikkat! Her yaşlı bireyde skor yüksek değil. Modelimiz yaşa çok güveniyorsa, bazı bireysel farklılıkları kaçırıyor olabilir.
# İşte bu yüzden model sadece yaşa bakmamalı, ses biyobelirteçlerini de dikkate almalı.”

# %%
import seaborn as sns
df['age_group'] = pd.cut(df['age'], bins=[30, 50, 60, 70, 90], labels=["30-50", "50-60", "60-70", "70+"])
sns.scatterplot(data=df, x='age', y='motor_UPDRS', hue='age_group')
# Out:
# <Axes: xlabel='age', ylabel='motor_UPDRS'>

# %% [markdown]
# SHAP ile her tahmin için “hangi değişken etkiliydi?” görebiliriz.
# Bu, özellikle düşük motor skorlu ama yaşlı bireylerde "neden?" sorusunu yanıtlamada çok yardımcı olur.

# %%
import shap

explainer = shap.TreeExplainer(model, X_train)
shap_values = explainer(X_test, check_additivity=False)
shap.summary_plot(shap_values, X_test)
# Out:
#  99%|===================| 1753/1763 [01:45<00:00]

# %% [markdown]
# Süper soru! 🎯
# SHAP (SHapley Additive exPlanations), makine öğrenmesi modellerini **anlaşılır**, **şeffaf** ve **açıklanabilir** hale getiren en güçlü araçlardan biridir. Özellikle eğitimde, sağlıkta, hukukta ve modelin karar vermesinin **"neden"** sorusuna cevap arandığı her yerde hayati öneme sahiptir.
#
# ---
#
# ## 🧠 SHAP Nedir?
#
# SHAP, bir modelin tahminini **özellik bazında açıklayan** bir yöntemdir.
#
# > “Model bu tahmini neden yaptı?”
# > “Hangi özellik bu tahmini artırdı veya azalttı?”
# > “Bu hasta neden yüksek riskli olarak sınıflandırıldı?”
#
# Bu tür sorulara **matematiksel olarak adil ve güvenilir bir şekilde** yanıt verir.
#
# ---
#
# ## 📊 SHAP Ne Yapar?
#
# Modelin her tahmini için:
#
# - **Beklenen tahmin (ortalama)** → `explainer.expected_value`
# - **Tahmin edilen değer** → `model.predict(...)`
# - **Her özelliğin tahmine katkısı** → `SHAP değeri`
#
# 🔁 Toplamda:
# ```python
# model output ≈ base_value + ∑ SHAP contributions
# ```
#
# ---
#
# ## 🎯 Neden SHAP Kullanmalıyım?
#
# | Sebep | Açıklama |
# |-------|----------|
# | ✅ Modeli anlamak | Özelliklerin yönü ve etkisini açıklar |
# | ✅ Güven vermek | “Model neden böyle karar verdi?” sorusuna şeffaf cevap |
# | ✅ Regülasyon | GDPR, KVKK gibi yasalar “açıklanabilir AI” ister |
# | ✅ Önyargı kontrolü | Cinsiyet, ırk gibi özelliklerin etkisini ölçebilirsin |
# | ✅ Özellik seçimi | En anlamlı değişkenleri tespit etmene yardımcı olur |
# | ✅ Eğitim amaçlı | Model karar mantığını örneklerle gösterir |
#
# ---
#
# ## 📍 SHAP Nerede Kullanılır?
#
# | Kullanım Alanı | SHAP Ne Sağlar? |
# |----------------|------------------|
# | **Sağlık**     | Hangi semptomlar hangi tanıyı tetikledi? |
# | **Finans**     | Bu müşteri neden riskli bulundu? |
# | **İK**         | Bu aday neden reddedildi? |
# | **Adli Sistem**| Tahminin hangi kriterlere dayandığını gösterir |
# | **Eğitim**     | Öğrencilere modelin içyüzünü sezgisel anlatır |
# | **Model geliştirme** | En anlamlı ve etkisiz değişkenleri net görürsün |
#
# ---
#
# ## 🔬 SHAP Nasıl Görselleştirilir?
#
# | Görsel | Ne Gösterir? |
# |--------|---------------|
# | `summary_plot` | Tüm veri setinde en etkili özellikler |
# | `force_plot`   | Bireysel tahmin açıklaması |
# | `dependence_plot` | Özelliğin değeri ile etkisi arasındaki ilişki |
# | `waterfall_plot` | Adım adım katkı açıklaması |
# | `decision_plot` | Tahmin yolunun tüm özelliklerle izahı |
#
# ---
#
# ## 🛠️ Hangi Modellerde Kullanılır?
#
# - 🎯 Tree modelleri (RandomForest, XGBoost, LightGBM) → **TreeExplainer**
# - 🔁 Linear modeller → **LinearExplainer**
# - 🧠 Neural network’ler → **DeepExplainer**
# - 🎲 Diğer modeller (kernel-based, black-box) → **KernelExplainer**
#
# ---
#
# ## 🎓 Özet:
#
# > SHAP, “model tahminini parçalarına ayırır” ve **her bir değişkenin ne kadar etkili olduğunu** gösterir.
# > Bu sayede sadece neyi tahmin ettiğini değil, **neden o sonucu verdiğini** de öğrenmiş oluruz.
